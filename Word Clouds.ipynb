# %% [markdown]
# # Dependencies

# %%
import os
import pickle

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from textblob import TextBlob

# %matplotlib inline

# %%
DIR_LOC = "."

# %% [markdown]
# # Data

# %% [markdown]
# Review data is the most interested dataset part and included
# more information. Therefore, we are planning to
# predict the star of a review will give. The restaurant review
# dataset contains 990627 reviews (63% of total reviews),
# which amounts to around 1GB of data. (*Section 2.4*)

# %%
reviews = pd.read_csv("data/yelp_review.csv")

# %% [markdown]
# Our dataset contains about 5$\times$ more reviews than the replication paper.

# %%
reviews.shape
# Out:
# (5261668, 9)

# %%
textGroupByStar = reviews.head(50000).groupby('stars')['text'].apply(' '.join).reset_index()

# %%
from wordcloud import WordCloud
#Generate a word cloud image
worldCloud1Star = WordCloud(max_font_size=40).generate(test.iloc[0]['text'])
plt.imshow(worldCloud1Star, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
from wordcloud import WordCloud
#Generate a word cloud image
worldCloud5Star = WordCloud(max_font_size=40).generate(test.iloc[4]['text'])
plt.imshow(worldCloud5Star, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
